# %% [markdown]
# ## **Deep Learning Made Easy**
#
# ----
#
# Author:  <a href="https://www.linkedin.com/in/valdivino-alexandre-de-santiago-j%C3%BAnior-103109206/?locale=en_US">Valdivino Alexandre de Santiago Júnior</a>.
#
# <br>
#
# **Licence**: GNU GENERAL PUBLIC LICENSE, Version 3 (GPLv3)
#
# <br>
#
# This is a notebook to demonstrate how easy is to create "new" deep neural networks (DNNs) by changing a few lines of code of previously proposed models and, hence, create new architectures. The <a href="https://github.com/pytorch/vision/blob/main/torchvision/models/densenet.py">DenseNet</a> deep convolutional neural network (CNN) by the PyTorch Team is modified to create a new architecture: DenseNet-83.

# %%
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change to "root" directory
# %cd /content/drive/My Drive/Colab Notebooks/pyTorch/dlme
# %ls
# Out:
# /content/drive/My Drive/Colab Notebooks/pyTorch/dlme
#  B16_DCGAN.ipynb
# 'Copy of PyTorch CIFAR-10_Valdivino SantiagoV2.ipynb'
# 'Copy of TOrC_TL_adapted.ipynb'
#  dcgan_faces_tutorialOriginal.ipynb
#  densenetmodified.py
#  imagenettetvt320/
#  imagenettetvt320.zip
#  out/
#  phasesdnn.py
#  __pycache__/
# 'PyTorch CIFAR-10_Valdivino Santiago.ipynb'
# 'PyTorch CIFAR-10_Valdivino Santiago_Profiler.ipynb'
# 'PyTorch CIFAR-10_Valdivino SantiagoV2.ipynb'
#  pytorch-deep-explainer-mnist-example.ipynb
#  PyTorch_DenseNet.ipynb
# 'PyTorch MNIST_Valdivino Santiago.ipynb'
# 'PyTorch MNIST_Valdivino Santiago_Profiler.ipynb'
# 'PyTorch MNIST_Valdivino SantiagoV2.ipynb'
# 'PyTorch_Semantic Segmentation.ipynb'
#  PyTorch_TransferLayer.ipynb
#  PyTorch_VGG_ResNet_ResNetonly.ipynb
#  resnetmodified.py
#  Ricardo_DL_UNet_CropExample.ipynb
#  user_options.txt
#  utilsdnn.py
#  utilsio.py
#  utilsmetrics.py
#  vggmodified.py

# %% [markdown]
# ## **Create directories and unzip the datasets**
# ----
#
# Create the following directories under the "root" directory:
#
#
#
# 1.   ```imagenettetvt320```. It will contain the <a href="https://github.com/fastai/imagenette">imagenette320 px</a> datasets. However, we split the original validation dataset into two: validation with 1/3 of the images of the original validation set, and 2/3 of the images compose the test dataset;
# 2.   ```out```. It is to store the best model during training and other relevant outputs.
#
# <br>
#
# After that, run the command below only once to unzip all datasets (training, validation, test). It is assumed that the .zip file (imagenettetvt320.zip) has already been uploaded to the "root" Google Drive's directory.

# %%
#!unzip "/content/drive/My Drive/Colab Notebooks/pyTorch/dlme/imagenettetvt320.zip" -d "/content/drive/My Drive/Colab Notebooks/pyTorch/dlme/imagenettetvt320"

# %% [markdown]
# ## **Modified models**
# ----
#
# Below, ```densenetmodified``` is the file with the modifications accomplished to created the new model. Take a look at it to precisely see the very few modifications which have been made.

# %%
from __future__ import print_function, division
import matplotlib.pyplot as plt
import numpy as np
import PIL
import torch
import torch.nn as nn
import torch.optim as optim
import sys
import os
import time
import torchvision
from torchvision import datasets, transforms # models: out
from densenetmodified import * # DenseNet modified
from prettytable import PrettyTable
from torch.autograd import Variable
plt.ion()   # Interactive mode

# %%
# This function obtains the number of trainable parameters of the 
# model/network.
def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total trainable params: {total_params}")
    return total_params

# %%
# Custom dataset that includes image file paths. Extends 
# torchvision.datasets.ImageFolder
class FileNames(datasets.ImageFolder):
    
    # Override the __getitem__ method. this is the method that dataloader calls
    def __getitem__(self, index):
        # This is what ImageFolder normally returns 
        original_tuple = super(FileNames, self).__getitem__(index)
        # The image file path
        path = self.imgs[index][0]
        # Make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

# %% [markdown]
# ## **Define important variables**
# ----
#
# Here, we define the classes and also some hyper-parameters.

# %%
# The directory of the datasets
data_dir = 'imagenettetvt320'

# All relevant outputs are here
output_dir = '/content/drive/My Drive/Colab Notebooks/pyTorch/dlme/out' 

# The number of classes
num_classes = 10

# Variables related to the selected CNN
indic = '' # Indicator of the selected CNN
hei_wid = 224 # Images will be cropped to 224 x 224

# Hyper-parameters
num_epochs = 10 # Number of epochs
batch_size = 4 # The size of input data took for one iteration
learning_rate = 0.001 # Learning rate
moment = 0.9 # Momentum

# %% [markdown]
# ## **Select the CNN and load data**
# ----
#
# Select the CNN and load data. All images are cropped below to 224 x 224 (variable ```hei_wid```). Moreover, note that dynamic data augmentation and
# normalisation are used for the training dataset only. For the validation and test datasets, only normalisation.

# %%
print("Select the CNN: ")
print("Press '1' for DenseNet-121.")
print("Press '2' for DenseNet-161.")
print("Press '3' for DenseNet-83 (new).")
opt = input("Enter your choice:")
if opt =='1':
	indic = 'DenseNet-121'
	print("You selected DenseNet-121!")
elif opt =='2':
	indic = 'DenseNet-161'
	print("You selected DenseNet-161!")
elif opt =='3':
	indic = 'DenseNet-83'
	print("You selected DenseNet-83 (new)!") 
else:
  print("Invalid Option!") 

# File that contains the best model obtained during the training phase
best_model_full = output_dir+'/best_model_'+indic+'.pt' 

# Tranformations for each dataset. Note that dynamic data augmentation and
# normalisation are used for the training dataset only. For the validation
# and test datasets, only normalisation.
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(hei_wid),
        transforms.RandomHorizontalFlip(),                         
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
        
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(hei_wid),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),

    'test': transforms.Compose([
        transforms.Resize(256),                        
        transforms.CenterCrop(hei_wid), 
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])
}

image_datasets = {x: FileNames(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val', 'test']}

dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=2)
              for x in ['train', 'val', 'test']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}

# Just checking the sizes
print('\nDataset sizes: ', dataset_sizes)
print('Dataloaders sizes: ', len(dataloaders))
class_names = image_datasets['train'].classes
class_namesv = image_datasets['val'].classes
class_namest = image_datasets['test'].classes
print('Training classes: ', class_names)
print('Training lengths: ', len(class_names))
print('Validation classes: ', class_namesv)
print('Validation lengths: ', len(class_namesv))
print('Test classes: ', class_namest)
print('Test lengths: ', len(class_namest))
print('Height x Width: {} x {}'.format(hei_wid,hei_wid))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# Select the CNN:
# Press '1' for DenseNet-121.
# Press '2' for DenseNet-161.
# Press '3' for DenseNet-83 (new).
# Enter your choice:3
# You selected DenseNet-83 (new)!
#
# Dataset sizes:  {'train': 9469, 'val': 1309, 'test': 2616}
# Dataloaders sizes:  3
# Training classes:  ['cassetePlayer', 'chainShaw', 'church', 'englishSpringer', 'frenchHorn', 'garbageTruck', 'gasPump', 'golfBall', 'parachute', 'tench']
# Training lengths:  10
# Validation classes:  ['cassetePlayer', 'chainSaw', 'church', 'englishSpringer', 'frenchHorn', 'garbageTruck', 'gasPump', 'golfBall', 'parachute', 'tench']
# Validation lengths:  10
# Test classes:  ['cassetePlayer', 'chainShaw', 'church', 'englishSpringer', 'frenchHorn', 'garbageTruck', 'gasPump', 'golfBall', 'parachute', 'tench']
# Test lengths:  10
# Height x Width: 224 x 224

# %%
# Just visualising some images
def visualise_images(img):
    img = img / 2 + 0.5     # Unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# Get a batch: training dataset
dataiter = iter(dataloaders['train'])
images, labels, paths = dataiter.next()
print('One batch - training dataset:', images.shape)

print('\nEach image of the batch:')
for i in range(labels.shape[0]):
  print('Image: {} - Input shape: {} - Class: {}'.format(i, images[i].shape, image_datasets['train'].classes[labels[i]]))
  if i == (labels.shape[0]-1):
    print('The "image" itself: ', images[i])

# Show images
visualise_images(torchvision.utils.make_grid(images))
# Print labels
print(' - '.join('%5s' % image_datasets['train'].classes[labels[j]] for j in range(batch_size)))
# Out:
# One batch - training dataset: torch.Size([4, 3, 224, 224])
#
# Each image of the batch:
# Image: 0 - Input shape: torch.Size([3, 224, 224]) - Class: cassetePlayer
# Image: 1 - Input shape: torch.Size([3, 224, 224]) - Class: chainShaw
# Image: 2 - Input shape: torch.Size([3, 224, 224]) - Class: cassetePlayer
# Image: 3 - Input shape: torch.Size([3, 224, 224]) - Class: church
# The "image" itself:  tensor([[[-0.0980, -0.0980, -0.0980,  ...,  0.1608,  0.1608,  0.1686],
#          [-0.0980, -0.0980, -0.0980,  ...,  0.1608,  0.1608,  0.1686],
#          [-0.0980, -0.0980, -0.0980,  ...,  0.1608,  0.1608,  0.1686],
#          ...,
#          [ 0.7020,  0.6941,  0.7020,  ..., -0.9843, -1.0000, -1.0000],
#          [ 0.6941,  0.6863,  0.6941,  ..., -0.6941, -0.6706, -0.6392],
#          [ 0.6941,  0.6863,  0.6863,  ..., -0.5059, -0.4588, -0.3961]],
#
#         [[ 0.2392,  0.2392,  0.2392,  ...,  0.4275,  0.4275,  0.4353],
#          [ 0.2392,  0.2392,  0.2392,  ...,  0.4275,  0.4275,  0.4353],
#          [ 0.2392,  0.2392,  0.2392,  ...,  0.4275,  0.4275,  0.4353],
#          ...,
#          [ 0.6314,  0.6235,  0.6392,  ..., -0.9843, -0.9922, -0.9843],
#          [ 0.6157,  0.6078,  0.6078,  ..., -0.6941, -0.6627, -0.6235],
#          [ 0.6000,  0.5922,  0.5922,  ..., -0.4980, -0.4510, -0.3882]],
#
#         [[ 0.6549,  0.6549,  0.6549,  ...,  0.7176,  0.7176,  0.7255],
#          [ 0.6549,  0.6549,  0.6549,  ...,  0.7176,  0.7176,  0.7255],
#          [ 0.6549,  0.6549,  0.6549,  ...,  0.7176,  0.7176,  0.7255],
#          ...,
#          [ 0.5137,  0.5059,  0.5137,  ..., -1.0000, -1.0000, -1.0000],
#          [ 0.4902,  0.4824,  0.4824,  ..., -0.7333, -0.6941, -0.6627],
#          [ 0.4745,  0.4667,  0.4667,  ..., -0.5529, -0.4980, -0.4353]]])
# cassetePlayer - chainShaw - cassetePlayer - church

# %% [markdown]
# ## **Instantiate the selected CNN**
# ----
#
# Now, we instantiate the previous selected CNN.

# %%
# Number of input features for the last layer (fully-connected)
num_ftrs = -1 
if opt =='1':
  net = densenet121()
  num_ftrs = net.classifier.in_features
  print('Input features - DenseNet-121:', num_ftrs) 
  net.classifier = nn.Linear(num_ftrs, num_classes)
elif opt =='2':
  net = densenet161()
  num_ftrs = net.classifier.in_features
  print('Input features - DenseNet-161:', num_ftrs)
  net.classifier = nn.Linear(num_ftrs, num_classes)
elif opt =='3':
  net = densenet83()
  num_ftrs = net.classifier.in_features
  print('Input features - DenseNet-83:', num_ftrs)
  net.classifier = nn.Linear(num_ftrs, num_classes)  
else:
  print("Invalid Option!")
     
net = net.to(device)
# Out:
# Input features - DenseNet-83: 1110

# %% [markdown]
# ## **Define loss function and optimiser**
#
# ----
#
# The <a href="https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html">CrossEntropyLoss</a> function combines LogSoftmax and NLLLoss in one single class. Optimiser is SGD, the learning rate and momentum have already been defined.

# %%
# Cross-entropy Loss
loss_function = nn.CrossEntropyLoss()

# All parameters are being optimised
optimiser = optim.SGD(net.parameters(), lr=learning_rate, momentum=moment)

print('Checking trainable parameters: {}'.format(count_parameters(net)))
# Out:
# +------------------------------------------------+------------+
# |                    Modules                     | Parameters |
# +------------------------------------------------+------------+
# |             features.conv0.weight              |   14112    |
# |             features.norm0.weight              |     96     |
# |              features.norm0.bias               |     96     |
# | features.denseblock1.denselayer1.norm1.weight  |     96     |
# |  features.denseblock1.denselayer1.norm1.bias   |     96     |
# | features.denseblock1.denselayer1.conv1.weight  |   18432    |
# | features.denseblock1.denselayer1.norm2.weight  |    192     |
# |  features.denseblock1.denselayer1.norm2.bias   |    192     |
# | features.denseblock1.denselayer1.conv2.weight  |   82944    |
# | features.denseblock1.denselayer2.norm1.weight  |    144     |
# |  features.denseblock1.denselayer2.norm1.bias   |    144     |
# | features.denseblock1.denselayer2.conv1.weight  |   27648    |
# | features.denseblock1.denselayer2.norm2.weight  |    192     |
# |  features.denseblock1.denselayer2.norm2.bias   |    192     |
# | features.denseblock1.denselayer2.conv2.weight  |   82944    |
# | features.denseblock1.denselayer3.norm1.weight  |    192     |
# |  features.denseblock1.denselayer3.norm1.bias   |    192     |
# | features.denseblock1.denselayer3.conv1.weight  |   36864    |
# | features.denseblock1.denselayer3.norm2.weight  |    192     |
# |  features.denseblock1.denselayer3.norm2.bias   |    192     |
# | features.denseblock1.denselayer3.conv2.weight  |   82944    |
# |        features.transition1.norm.weight        |    240     |
# |         features.transition1.norm.bias         |    240     |
# |        features.transition1.conv.weight        |   28800    |
# | features.denseblock2.denselayer1.norm1.weight  |    120     |
# |  features.denseblock2.denselayer1.norm1.bias   |    120     |
# | features.denseblock2.denselayer1.conv1.weight  |   23040    |
# | features.denseblock2.denselayer1.norm2.weight  |    192     |
# |  features.denseblock2.denselayer1.norm2.bias   |    192     |
# | features.denseblock2.denselayer1.conv2.weight  |   82944    |
# | features.denseblock2.denselayer2.norm1.weight  |    168     |
# |  features.denseblock2.denselayer2.norm1.bias   |    168     |
# | features.denseblock2.denselayer2.conv1.weight  |   32256    |
# | features.denseblock2.denselayer2.norm2.weight  |    192     |
# |  features.denseblock2.denselayer2.norm2.bias   |    192     |
# | features.denseblock2.denselayer2.conv2.weight  |   82944    |
# | features.denseblock2.denselayer3.norm1.weight  |    216     |
# |  features.denseblock2.denselayer3.norm1.bias   |    216     |
# | features.denseblock2.denselayer3.conv1.weight  |   41472    |
# | features.denseblock2.denselayer3.norm2.weight  |    192     |
# |  features.denseblock2.denselayer3.norm2.bias   |    192     |
# | features.denseblock2.denselayer3.conv2.weight  |   82944    |
# | features.denseblock2.denselayer4.norm1.weight  |    264     |
# |  features.denseblock2.denselayer4.norm1.bias   |    264     |
# | features.denseblock2.denselayer4.conv1.weight  |   50688    |
# | features.denseblock2.denselayer4.norm2.weight  |    192     |
# |  features.denseblock2.denselayer4.norm2.bias   |    192     |
# | features.denseblock2.denselayer4.conv2.weight  |   82944    |
# | features.denseblock2.denselayer5.norm1.weight  |    312     |
# |  features.denseblock2.denselayer5.norm1.bias   |    312     |
# | features.denseblock2.denselayer5.conv1.weight  |   59904    |
# | features.denseblock2.denselayer5.norm2.weight  |    192     |
# |  features.denseblock2.denselayer5.norm2.bias   |    192     |
# | features.denseblock2.denselayer5.conv2.weight  |   82944    |
# | features.denseblock2.denselayer6.norm1.weight  |    360     |
# |  features.denseblock2.denselayer6.norm1.bias   |    360     |
# | features.denseblock2.denselayer6.conv1.weight  |   69120    |
# | features.denseblock2.denselayer6.norm2.weight  |    192     |
# |  features.denseblock2.denselayer6.norm2.bias   |    192     |
# | features.denseblock2.denselayer6.conv2.weight  |   82944    |
# |        features.transition2.norm.weight        |    408     |
# |         features.transition2.norm.bias         |    408     |
# |        features.transition2.conv.weight        |   83232    |
# | features.denseblock3.denselayer1.norm1.weight  |    204     |
# |  features.denseblock3.denselayer1.norm1.bias   |    204     |
# | features.denseblock3.denselayer1.conv1.weight  |   39168    |
# | features.denseblock3.denselayer1.norm2.weight  |    192     |
# |  features.denseblock3.denselayer1.norm2.bias   |    192     |
# | features.denseblock3.denselayer1.conv2.weight  |   82944    |
# | features.denseblock3.denselayer2.norm1.weight  |    252     |
# |  features.denseblock3.denselayer2.norm1.bias   |    252     |
# | features.denseblock3.denselayer2.conv1.weight  |   48384    |
# | features.denseblock3.denselayer2.norm2.weight  |    192     |
# |  features.denseblock3.denselayer2.norm2.bias   |    192     |
# | features.denseblock3.denselayer2.conv2.weight  |   82944    |
# | features.denseblock3.denselayer3.norm1.weight  |    300     |
# |  features.denseblock3.denselayer3.norm1.bias   |    300     |
# | features.denseblock3.denselayer3.conv1.weight  |   57600    |
# | features.denseblock3.denselayer3.norm2.weight  |    192     |
# |  features.denseblock3.denselayer3.norm2.bias   |    192     |
# | features.denseblock3.denselayer3.conv2.weight  |   82944    |
# | features.denseblock3.denselayer4.norm1.weight  |    348     |
# |  features.denseblock3.denselayer4.norm1.bias   |    348     |
# | features.denseblock3.denselayer4.conv1.weight  |   66816    |
# | features.denseblock3.denselayer4.norm2.weight  |    192     |
# |  features.denseblock3.denselayer4.norm2.bias   |    192     |
# | features.denseblock3.denselayer4.conv2.weight  |   82944    |
# | features.denseblock3.denselayer5.norm1.weight  |    396     |
# |  features.denseblock3.denselayer5.norm1.bias   |    396     |
# | features.denseblock3.denselayer5.conv1.weight  |   76032    |
# | features.denseblock3.denselayer5.norm2.weight  |    192     |
# |  features.denseblock3.denselayer5.norm2.bias   |    192     |
# | features.denseblock3.denselayer5.conv2.weight  |   82944    |
# | features.denseblock3.denselayer6.norm1.weight  |    444     |
# |  features.denseblock3.denselayer6.norm1.bias   |    444     |
# | features.denseblock3.denselayer6.conv1.weight  |   85248    |
# | features.denseblock3.denselayer6.norm2.weight  |    192     |
# |  features.denseblock3.denselayer6.norm2.bias   |    192     |
# | features.denseblock3.denselayer6.conv2.weight  |   82944    |
# | features.denseblock3.denselayer7.norm1.weight  |    492     |
# |  features.denseblock3.denselayer7.norm1.bias   |    492     |
# | features.denseblock3.denselayer7.conv1.weight  |   94464    |
# | features.denseblock3.denselayer7.norm2.weight  |    192     |
# |  features.denseblock3.denselayer7.norm2.bias   |    192     |
# | features.denseblock3.denselayer7.conv2.weight  |   82944    |
# | features.denseblock3.denselayer8.norm1.weight  |    540     |
# |  features.denseblock3.denselayer8.norm1.bias   |    540     |
# | features.denseblock3.denselayer8.conv1.weight  |   103680   |
# | features.denseblock3.denselayer8.norm2.weight  |    192     |
# |  features.denseblock3.denselayer8.norm2.bias   |    192     |
# | features.denseblock3.denselayer8.conv2.weight  |   82944    |
# | features.denseblock3.denselayer9.norm1.weight  |    588     |
# |  features.denseblock3.denselayer9.norm1.bias   |    588     |
# | features.denseblock3.denselayer9.conv1.weight  |   112896   |
# | features.denseblock3.denselayer9.norm2.weight  |    192     |
# |  features.denseblock3.denselayer9.norm2.bias   |    192     |
# | features.denseblock3.denselayer9.conv2.weight  |   82944    |
# | features.denseblock3.denselayer10.norm1.weight |    636     |
# |  features.denseblock3.denselayer10.norm1.bias  |    636     |
# | features.denseblock3.denselayer10.conv1.weight |   122112   |
# | features.denseblock3.denselayer10.norm2.weight |    192     |
# |  features.denseblock3.denselayer10.norm2.bias  |    192     |
# | features.denseblock3.denselayer10.conv2.weight |   82944    |
# | features.denseblock3.denselayer11.norm1.weight |    684     |
# |  features.denseblock3.denselayer11.norm1.bias  |    684     |
# | features.denseblock3.denselayer11.conv1.weight |   131328   |
# | features.denseblock3.denselayer11.norm2.weight |    192     |
# |  features.denseblock3.denselayer11.norm2.bias  |    192     |
# | features.denseblock3.denselayer11.conv2.weight |   82944    |
# | features.denseblock3.denselayer12.norm1.weight |    732     |
# |  features.denseblock3.denselayer12.norm1.bias  |    732     |
# | features.denseblock3.denselayer12.conv1.weight |   140544   |
# | features.denseblock3.denselayer12.norm2.weight |    192     |
# |  features.denseblock3.denselayer12.norm2.bias  |    192     |
# | features.denseblock3.denselayer12.conv2.weight |   82944    |
# | features.denseblock3.denselayer13.norm1.weight |    780     |
# |  features.denseblock3.denselayer13.norm1.bias  |    780     |
# | features.denseblock3.denselayer13.conv1.weight |   149760   |
# | features.denseblock3.denselayer13.norm2.weight |    192     |
# |  features.denseblock3.denselayer13.norm2.bias  |    192     |
# | features.denseblock3.denselayer13.conv2.weight |   82944    |
# | features.denseblock3.denselayer14.norm1.weight |    828     |
# |  features.denseblock3.denselayer14.norm1.bias  |    828     |
# | features.denseblock3.denselayer14.conv1.weight |   158976   |
# | features.denseblock3.denselayer14.norm2.weight |    192     |
# |  features.denseblock3.denselayer14.norm2.bias  |    192     |
# | features.denseblock3.denselayer14.conv2.weight |   82944    |
# | features.denseblock3.denselayer15.norm1.weight |    876     |
# |  features.denseblock3.denselayer15.norm1.bias  |    876     |
# | features.denseblock3.denselayer15.conv1.weight |   168192   |
# | features.denseblock3.denselayer15.norm2.weight |    192     |
# |  features.denseblock3.denselayer15.norm2.bias  |    192     |
# | features.denseblock3.denselayer15.conv2.weight |   82944    |
# | features.denseblock3.denselayer16.norm1.weight |    924     |
# |  features.denseblock3.denselayer16.norm1.bias  |    924     |
# | features.denseblock3.denselayer16.conv1.weight |   177408   |
# | features.denseblock3.denselayer16.norm2.weight |    192     |
# |  features.denseblock3.denselayer16.norm2.bias  |    192     |
# | features.denseblock3.denselayer16.conv2.weight |   82944    |
# | features.denseblock3.denselayer17.norm1.weight |    972     |
# |  features.denseblock3.denselayer17.norm1.bias  |    972     |
# | features.denseblock3.denselayer17.conv1.weight |   186624   |
# | features.denseblock3.denselayer17.norm2.weight |    192     |
# |  features.denseblock3.denselayer17.norm2.bias  |    192     |
# | features.denseblock3.denselayer17.conv2.weight |   82944    |
# | features.denseblock3.denselayer18.norm1.weight |    1020    |
# |  features.denseblock3.denselayer18.norm1.bias  |    1020    |
# | features.denseblock3.denselayer18.conv1.weight |   195840   |
# | features.denseblock3.denselayer18.norm2.weight |    192     |
# |  features.denseblock3.denselayer18.norm2.bias  |    192     |
# | features.denseblock3.denselayer18.conv2.weight |   82944    |
# |        features.transition3.norm.weight        |    1068    |
# |         features.transition3.norm.bias         |    1068    |
# |        features.transition3.conv.weight        |   570312   |
# | features.denseblock4.denselayer1.norm1.weight  |    534     |
# |  features.denseblock4.denselayer1.norm1.bias   |    534     |
# | features.denseblock4.denselayer1.conv1.weight  |   102528   |
# | features.denseblock4.denselayer1.norm2.weight  |    192     |
# |  features.denseblock4.denselayer1.norm2.bias   |    192     |
# | features.denseblock4.denselayer1.conv2.weight  |   82944    |
# | features.denseblock4.denselayer2.norm1.weight  |    582     |
# |  features.denseblock4.denselayer2.norm1.bias   |    582     |
# | features.denseblock4.denselayer2.conv1.weight  |   111744   |
# | features.denseblock4.denselayer2.norm2.weight  |    192     |
# |  features.denseblock4.denselayer2.norm2.bias   |    192     |
# | features.denseblock4.denselayer2.conv2.weight  |   82944    |
# | features.denseblock4.denselayer3.norm1.weight  |    630     |
# |  features.denseblock4.denselayer3.norm1.bias   |    630     |
# | features.denseblock4.denselayer3.conv1.weight  |   120960   |
# | features.denseblock4.denselayer3.norm2.weight  |    192     |
# |  features.denseblock4.denselayer3.norm2.bias   |    192     |
# | features.denseblock4.denselayer3.conv2.weight  |   82944    |
# | features.denseblock4.denselayer4.norm1.weight  |    678     |
# |  features.denseblock4.denselayer4.norm1.bias   |    678     |
# | features.denseblock4.denselayer4.conv1.weight  |   130176   |
# | features.denseblock4.denselayer4.norm2.weight  |    192     |
# |  features.denseblock4.denselayer4.norm2.bias   |    192     |
# | features.denseblock4.denselayer4.conv2.weight  |   82944    |
# | features.denseblock4.denselayer5.norm1.weight  |    726     |
# |  features.denseblock4.denselayer5.norm1.bias   |    726     |
# | features.denseblock4.denselayer5.conv1.weight  |   139392   |
# | features.denseblock4.denselayer5.norm2.weight  |    192     |
# |  features.denseblock4.denselayer5.norm2.bias   |    192     |
# | features.denseblock4.denselayer5.conv2.weight  |   82944    |
# | features.denseblock4.denselayer6.norm1.weight  |    774     |
# |  features.denseblock4.denselayer6.norm1.bias   |    774     |
# | features.denseblock4.denselayer6.conv1.weight  |   148608   |
# | features.denseblock4.denselayer6.norm2.weight  |    192     |
# |  features.denseblock4.denselayer6.norm2.bias   |    192     |
# | features.denseblock4.denselayer6.conv2.weight  |   82944    |
# | features.denseblock4.denselayer7.norm1.weight  |    822     |
# |  features.denseblock4.denselayer7.norm1.bias   |    822     |
# | features.denseblock4.denselayer7.conv1.weight  |   157824   |
# | features.denseblock4.denselayer7.norm2.weight  |    192     |
# |  features.denseblock4.denselayer7.norm2.bias   |    192     |
# | features.denseblock4.denselayer7.conv2.weight  |   82944    |
# | features.denseblock4.denselayer8.norm1.weight  |    870     |
# |  features.denseblock4.denselayer8.norm1.bias   |    870     |
# | features.denseblock4.denselayer8.conv1.weight  |   167040   |
# | features.denseblock4.denselayer8.norm2.weight  |    192     |
# |  features.denseblock4.denselayer8.norm2.bias   |    192     |
# | features.denseblock4.denselayer8.conv2.weight  |   82944    |
# | features.denseblock4.denselayer9.norm1.weight  |    918     |
# |  features.denseblock4.denselayer9.norm1.bias   |    918     |
# | features.denseblock4.denselayer9.conv1.weight  |   176256   |
# | features.denseblock4.denselayer9.norm2.weight  |    192     |
# |  features.denseblock4.denselayer9.norm2.bias   |    192     |
# | features.denseblock4.denselayer9.conv2.weight  |   82944    |
# | features.denseblock4.denselayer10.norm1.weight |    966     |
# |  features.denseblock4.denselayer10.norm1.bias  |    966     |
# | features.denseblock4.denselayer10.conv1.weight |   185472   |
# | features.denseblock4.denselayer10.norm2.weight |    192     |
# |  features.denseblock4.denselayer10.norm2.bias  |    192     |
# | features.denseblock4.denselayer10.conv2.weight |   82944    |
# | features.denseblock4.denselayer11.norm1.weight |    1014    |
# |  features.denseblock4.denselayer11.norm1.bias  |    1014    |
# | features.denseblock4.denselayer11.conv1.weight |   194688   |
# | features.denseblock4.denselayer11.norm2.weight |    192     |
# |  features.denseblock4.denselayer11.norm2.bias  |    192     |
# | features.denseblock4.denselayer11.conv2.weight |   82944    |
# | features.denseblock4.denselayer12.norm1.weight |    1062    |
# |  features.denseblock4.denselayer12.norm1.bias  |    1062    |
# | features.denseblock4.denselayer12.conv1.weight |   203904   |
# | features.denseblock4.denselayer12.norm2.weight |    192     |
# |  features.denseblock4.denselayer12.norm2.bias  |    192     |
# | features.denseblock4.denselayer12.conv2.weight |   82944    |
# |             features.norm5.weight              |    1110    |
# |              features.norm5.bias               |    1110    |
# |               classifier.weight                |   11100    |
# |                classifier.bias                 |     10     |
# +------------------------------------------------+------------+
# Total trainable params: 8321218
# Checking trainable parameters: 8321218

# %% [markdown]
# ## **Run the Training Phase**
# ----
#
# Now, we can run the training phase.

# %%
train_losses = []
train_acc = []
val_losses = []
val_acc = []
best_loss_validation = sys.float_info.max
best_epoch = sys.float_info.max
train_time_init = time.time()
#### Main training loop: Begin
for epoch in range(num_epochs):
  #### Each epoch has a training and validation phase: Begin
  for phase in ['train', 'val']:
    if phase == 'train':
      net.train() # Set model to training mode
    else:
      net.eval()  # Set model to evaluate mode
   
    running_loss = 0.0
    running_corrects = 0
    # Iterate over data: Begin
    for images, labels, paths in dataloaders[phase]: 
      images = Variable(images).to(device) # Send to GPU
      labels = Variable(labels).to(device) # Send to GPU
    
      optimiser.zero_grad()
      with torch.set_grad_enabled(phase == 'train'):
        outputs = net(images)
        _, preds = torch.max(outputs, 1)
        loss = loss_function(outputs, labels)
        
        # Backward + optimise only if in training phase. 
        if phase == 'train':
          loss.backward()
          optimiser.step()
    
      running_loss += loss.item() * images.size(0)
      running_corrects += torch.sum(preds == labels.data)
    # Iterate over data: End

    epoch_loss = running_loss / dataset_sizes[phase]
    epoch_acc = running_corrects.double() / dataset_sizes[phase] 
    print('Phase: {}, Epoch {}/{}, Loss: {:.4f}, Accuracy: {:.4f}'.format(
                 phase, epoch+1, num_epochs, epoch_loss, epoch_acc))
    
    if phase == 'train': # Training
      train_losses.append(epoch_loss)
      train_acc.append(epoch_acc) 
    else: # Validation
      val_losses.append(epoch_loss)
      val_acc.append(epoch_acc) 
      if (epoch_loss < best_loss_validation):
        best_loss_validation = epoch_loss
        best_epoch = epoch + 1
        if os.path.exists(best_model_full):
          os.remove(best_model_full)
          print('####### Validation loss: previous best model removed!!!!')
        else:
          print("####### Validation loss: there is no saved model yet!!!!")
        torch.save(net.state_dict(), best_model_full)
        print('####### Validation loss: new best model saved in Epoch: {} !!!!'.format(str(epoch + 1)))
  #### Each epoch has a training and validation phase: End
#### Main training loop: End
train_time_end = time.time() - train_time_init
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Phase: train, Epoch 1/10, Loss: 1.9627, Accuracy: 0.3147
# Phase: val, Epoch 1/10, Loss: 1.8785, Accuracy: 0.4629
# ####### Validation loss: there is no saved model yet!!!!
# ####### Validation loss: new best model saved in Epoch: 1 !!!!
# Phase: train, Epoch 2/10, Loss: 1.6820, Accuracy: 0.4362
# Phase: val, Epoch 2/10, Loss: 2.4453, Accuracy: 0.4920
# Phase: train, Epoch 3/10, Loss: 1.5395, Accuracy: 0.4936
# Phase: val, Epoch 3/10, Loss: 1.5053, Accuracy: 0.5798
# ####### Validation loss: previous best model removed!!!!
# ####### Validation loss: new best model saved in Epoch: 3 !!!!
# Phase: train, Epoch 4/10, Loss: 1.4511, Accuracy: 0.5224
# Phase: val, Epoch 4/10, Loss: 1.5988, Accuracy: 0.6371
# Phase: train, Epoch 5/10, Loss: 1.3744, Accuracy: 0.5573
# Phase: val, Epoch 5/10, Loss: 1.7820, Accuracy: 0.6196
# Phase: train, Epoch 6/10, Loss: 1.2928, Accuracy: 0.5831
# Phase: val, Epoch 6/10, Loss: 1.1111, Accuracy: 0.6822
# ####### Validation loss: previous best model removed!!!!
# ####### Validation loss: new best model saved in Epoch: 6 !!!!
# Phase: train, Epoch 7/10, Loss: 1.2619, Accuracy: 0.5941
# Phase: val, Epoch 7/10, Loss: 1.4066, Accuracy: 0.6547
# Phase: train, Epoch 8/10, Loss: 1.2109, Accuracy: 0.6169
# Phase: val, Epoch 8/10, Loss: 1.1951, Accuracy: 0.6906
# Phase: train, Epoch 9/10, Loss: 1.1722, Accuracy: 0.6236
# Phase: val, Epoch 9/10, Loss: 1.1950, Accuracy: 0.7212
# Phase: train, Epoch 10/10, Loss: 1.1256, Accuracy: 0.6425
# Phase: val, Epoch 10/10, Loss: 0.9661, Accuracy: 0.7265
# ####### Validation loss: previous best model removed!!!!
# ####### Validation loss: new best model saved in Epoch: 10 !!!!

# %% [markdown]
# ## **Training phase: results**
# ----
#
# Just showing the loss and accuracy during the training phase: training and validation datasets.

# %%
x = range(1,len(train_losses)+1)

plt.figure(figsize=(8,4))
plt.title("Training Phase: Loss")
plt.plot(x,train_losses,label="Train")
plt.plot(x,val_losses,label="Val")
plt.xticks(range(1,len(x)+1))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.savefig(f"{output_dir}/training_loss_"+indic+".png")
plt.show()

plt.figure(figsize=(8,4))
plt.title("Training Phase: Accuracy")
plt.plot(x,train_acc,label="Train")
plt.plot(x,val_acc,label="Val")
plt.xticks(range(1,len(x)+1))
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.savefig(f"{output_dir}/training_acc_"+indic+".png")
plt.show()

# %% [markdown]
# ## **Load the model**
# ----
#
# You can load your best model to use in the inference phase.

# %%
if opt =='1':
  net = densenet121()
  net.classifier = nn.Linear(num_ftrs, num_classes)
elif opt =='2':
  net = densenet161()
  net.classifier = nn.Linear(num_ftrs, num_classes)
elif opt =='3':
  net = densenet83()
  net.classifier = nn.Linear(num_ftrs, num_classes)
else:
  print("Invalid Option!")
     
net = net.to(device)
net.load_state_dict(torch.load(best_model_full))
print("Best {} model loaded!".format(indic))
# Out:
# Best DenseNet-83 model loaded!

# %% [markdown]
# ## **Inference phase**
#
# ----
#
# In the inference phase, we measure the performance of our model based on the test dataset.

# %%
am_training = net.training
print('Am I training? ', am_training)
net.eval()
am_training = net.training
print('Am I training? ', am_training)
inference_loss = 0.0
inference_corrects = 0
phase = 'test'

infer_time_init = time.time()
with torch.no_grad():
  # Iterate over data: Begin
  for images, labels, paths in dataloaders[phase]: 
      images = Variable(images).to(device) # Send to GPU
      labels = Variable(labels).to(device) # Send to GPU

      outputs_infer = net(images)
      _, preds_infer = torch.max(outputs_infer,1)
      loss_infer = loss_function(outputs_infer, labels)

      inference_loss += loss_infer.item() * images.size(0)
      inference_corrects += torch.sum(preds_infer == labels.data)
  # Iterate over data: End

final_inference_loss = inference_loss / dataset_sizes[phase]
final_inference_acc = inference_corrects.double() / dataset_sizes[phase]

infer_time_end = time.time() - infer_time_init
print('\nTraining and inference in {:.0f}m {:.0f}s  OR  {:.0f}s'.format(
        (train_time_end + infer_time_end) // 60, 
        (train_time_end + infer_time_end) % 60,
         train_time_end + infer_time_end))

print('\nLoss of {}: {:.4f}'.format(indic, final_inference_loss))
print()
print('Accuracy of {}: {:.4f}'.format(indic, final_inference_acc))
# Out:
# Am I training?  True
# Am I training?  False
#
# Training and inference in 144m 44s  OR  8684s
#
# Loss of DenseNet-83: 1.1237
#
# Accuracy of DenseNet-83: 0.7305

# %%
plt.ioff()
